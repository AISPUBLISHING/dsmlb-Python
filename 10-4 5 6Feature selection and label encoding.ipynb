# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('data/studentData.csv')

# %%
df.head()
# Out:
#                  name  thenthScore  twelthScore  firstSemScore  \
# 0       aastha gyanee          9.9          8.3            8.8
# 1      praveen sharma          8.1          7.9            7.8
# 2       kishan tiwari          9.5          9.0            7.8
# 3  radheshyam shankar          9.9          8.9            7.0
# 4        hariom pawar          9.1          8.1            9.0
#
#    secondSemScore  thirdSemScore  fourthSemScore  fifthSemScore  attendance  \
# 0             7.2            8.8             8.0            7.1         6.1
# 1             8.7            7.4             7.0            7.8         8.2
# 2             7.0            9.0             8.0            8.2         7.4
# 3             8.3            7.7             9.0            9.0         8.3
# 4             7.4            7.1             8.3            8.0         8.8
#
#    numberOfCertifications favouriteLanguage     workingField placed
# 0                       4            python  Web Development    yes
# 1                       5              java  Web Development    yes
# 2                       4         anuglarjs  Web Development    yes
# 3                       3            nodejs  Web Development    yes
# 4                       4               sql  Web Development    yes

# %%
df = df.drop('name', 1)

# %%
df.head()
# Out:
#    thenthScore  twelthScore  firstSemScore  secondSemScore  thirdSemScore  \
# 0          9.9          8.3            8.8             7.2            8.8
# 1          8.1          7.9            7.8             8.7            7.4
# 2          9.5          9.0            7.8             7.0            9.0
# 3          9.9          8.9            7.0             8.3            7.7
# 4          9.1          8.1            9.0             7.4            7.1
#
#    fourthSemScore  fifthSemScore  attendance  numberOfCertifications  \
# 0             8.0            7.1         6.1                       4
# 1             7.0            7.8         8.2                       5
# 2             8.0            8.2         7.4                       4
# 3             9.0            9.0         8.3                       3
# 4             8.3            8.0         8.8                       4
#
#   favouriteLanguage     workingField placed
# 0            python  Web Development    yes
# 1              java  Web Development    yes
# 2         anuglarjs  Web Development    yes
# 3            nodejs  Web Development    yes
# 4               sql  Web Development    yes

# %%
le = LabelEncoder()

for column in df[["favouriteLanguage", "workingField"]].columns:
        df[column] = le.fit_transform(df[column].values)

# %%
df.head()
# Out:
#    thenthScore  twelthScore  firstSemScore  secondSemScore  thirdSemScore  \
# 0          9.9          8.3            8.8             7.2            8.8
# 1          8.1          7.9            7.8             8.7            7.4
# 2          9.5          9.0            7.8             7.0            9.0
# 3          9.9          8.9            7.0             8.3            7.7
# 4          9.1          8.1            9.0             7.4            7.1
#
#    fourthSemScore  fifthSemScore  attendance  numberOfCertifications  \
# 0             8.0            7.1         6.1                       4
# 1             7.0            7.8         8.2                       5
# 2             8.0            8.2         7.4                       4
# 3             9.0            9.0         8.3                       3
# 4             8.3            8.0         8.8                       4
#
#    favouriteLanguage  workingField placed
# 0                 12            12    yes
# 1                  8            12    yes
# 2                  7            12    yes
# 3                 10            12    yes
# 4                 13            12    yes

# %%
y = df.placed.values
X = df.drop('placed', axis = 1).values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state=21, stratify=y)
knn = KNeighborsClassifier(n_neighbors=8)
knn.fit(X_train, y_train)
print(knn.score(X_test, y_test))
# Out:
# 1.0

# %%
z = [[8.6,  7.7,  7.5 ,  7.5,  7.5,  6.8,  7.3 ,  6.0 ,  3 , 8 , 1 ]]
print(knn.predict(z))
# Out:
# ['yes']
